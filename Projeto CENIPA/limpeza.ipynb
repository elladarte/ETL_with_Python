# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# ## Importando as Bilbiotecas

# %%
import pandas as pd

# %% [markdown]
# ## Extraindo os dados

# %%
dataframe = pd.read_csv('data/ocorrencia_2010_2020.csv',  sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
dataframe.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %% [markdown]
# Localizando indices e labels do dataframe

# %%
dataframe.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
dataframe.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# ...

# %%
dataframe.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# ...

# %%
dataframe.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %% [markdown]
# ## ALterando o indice do dataframe

# %% [markdown]
# Verificando os atributos que possuem valores unicos

# %%
dataframe.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# O atributo codigo_ocorrencia pode ser utilizado como indice por possuirem valores unicos

# %%
dataframe.set_index('codigo_ocorrencia', inplace=True)
dataframe
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
# ...                               ...                 ...                 ...
# 79804                           79804               79804               79804
# 79757                           79757               79757               79757
# 79802                           79802               79802               79802
# 79756                           79756               79756               79756
# 79844                           79844               79844               79844
#
# ...

# %%
dataframe.loc[40324]
# Out:
# codigo_ocorrencia1                              40324
# codigo_ocorrencia2                              40324
# codigo_ocorrencia3                              40324
# codigo_ocorrencia4                              40324
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                             PELOTAS
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBPK
# ocorrencia_dia                    2010-01-05 00:00:00
# ocorrencia_hora                              19:25:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# ...

# %% [markdown]
# Resetando o indice criado do dataframe

# %%
dataframe.reset_index(drop=True, inplace=True)

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
dataframe.loc[0,'ocorrencia_aerodromo'] = ''

# %%
dataframe.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
#
# [1 rows x 21 columns]

# %%
dataframe.loc[1] = 20

# %%
dataframe.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2010-01-03 00:00:00        12:00:00                            SIM
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# ...

# %%
dataframe.loc[:,'total_recomendacoes'] = 10

# %%
dataframe
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 5747               79804               79804               79804
# 5748               79757               79757               79757
# 5749               79802               79802               79802
# 5750               79756               79756               79756
# 5751               79844               79844               79844
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
dataframe['ocorrencia_uf_bkp'] = dataframe.ocorrencia_uf

# %%
dataframe
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 5747               79804               79804               79804
# 5748               79757               79757               79757
# 5749               79802               79802               79802
# 5750               79756               79756               79756
# 5751               79844               79844               79844
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
dataframe.loc[dataframe.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
dataframe
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 5747               79804               79804               79804
# 5748               79757               79757               79757
# 5749               79802               79802               79802
# 5750               79756               79756               79756
# 5751               79844               79844               79844
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
dataframe.loc[dataframe.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 11                 40069               40069               40069
# 16                 39809               39809               39809
# 18                 39828               39828               39828
# 26                 39847               39847               39847
# 27                 39768               39768               39768
# ...                  ...                 ...                 ...
# 5704               79739               79739               79739
# 5705               79705               79705               79705
# 5715               79718               79718               79718
# 5742               79800               79800               79800
# 5747               79804               79804               79804
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 11                 40069                    GRAVE      -23.5069444444
# ...

# %% [markdown]
# ## Limpando os dados

# %%
dataframe.loc[dataframe.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
dataframe.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
dataframe.isna().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1568
# ocorrencia_longitude              1569
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2348
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     341
# investigacao_status                340
# divulgacao_relatorio_numero        871
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4257
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1568
# ocorrencia_longitude              1569
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2348
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     341
# investigacao_status                340
# divulgacao_relatorio_numero        871
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4257
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
dataframe.fillna(10, inplace=True)

# %%
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# ocorrencia_uf_bkp                 0
# dtype: int64

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1                  20                       20                  20
# 2               40351                INCIDENTE                  10
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                  10
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
dataframe.replace([10], pd.NA, inplace=True)

# %%
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1568
# ocorrencia_longitude              1569
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2348
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     341
# investigacao_status                340
# divulgacao_relatorio_numero        871
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4257
# total_recomendacoes               5752
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
dataframe.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1568
# ocorrencia_longitude              1569
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2348
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     341
# investigacao_status                340
# divulgacao_relatorio_numero        871
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4257
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
dataframe['total_recomendacoes_bkp'] = dataframe.total_recomendacoes

# %%
dataframe.head()
# Out:
#   codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3 codigo_ocorrencia4  \
# 0              40211              40211              40211              40211
# 1                 20                 20                 20                 20
# 2              40351              40351              40351              40351
# 3              39527              39527              39527              39527
# 4              40324              40324              40324              40324
#
#   ocorrencia_classificacao ocorrencia_latitude ocorrencia_longitude  \
# 0                INCIDENTE                 ***                  ***
# 1                       20                  20                   20
# 2                INCIDENTE                <NA>                 <NA>
# 3                 ACIDENTE      -13.1066666667       -55.9930555556
# 4                INCIDENTE                <NA>                 <NA>
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# ...

# %%
dataframe.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
dataframe.dropna()
# Out:
#      codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 1                    20                 20                 20
# 8                 39156              39156              39156
# 11                40069              40069              40069
# 14                40107              40107              40107
# 29                39709              39709              39709
# ...                 ...                ...                ...
# 4873              78626              78626              78626
# 4935              78828              78828              78828
# 4971              78749              78749              78749
# 5008              78766              78766              78766
# 5280              79124              79124              79124
#
#      codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 1                    20                       20                  20
# 8                 39156          INCIDENTE GRAVE      -15.2402777778
# ...

# %%
dataframe.dropna(subset=['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 0                 40211              40211              40211
# 1                    20                 20                 20
# 2                 40351              40351              40351
# 3                 39527              39527              39527
# 4                 40324              40324              40324
# ...                 ...                ...                ...
# 5747              79804              79804              79804
# 5748              79757              79757              79757
# 5749              79802              79802              79802
# 5750              79756              79756              79756
# 5751              79844              79844              79844
#
#      codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                 40211                INCIDENTE                 ***
# 1                    20                       20                  20
# ...

# %%
dataframe.drop_duplicates(inplace=True)

# %%
dataframe
# Out:
#      codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 0                 40211              40211              40211
# 1                    20                 20                 20
# 2                 40351              40351              40351
# 3                 39527              39527              39527
# 4                 40324              40324              40324
# ...                 ...                ...                ...
# 5747              79804              79804              79804
# 5748              79757              79757              79757
# 5749              79802              79802              79802
# 5750              79756              79756              79756
# 5751              79844              79844              79844
#
#      codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                 40211                INCIDENTE                 ***
# 1                    20                       20                  20
# ...
